# %% [markdown]
# # Stroke Prediction

# %% [markdown]
# According to the World Health Organization (WHO) stroke is the 2nd leading cause of death globally, responsible for approximately 11% of total deaths. This dataset is used to predict whether a patient is likely to get stroke based on the input parameters like gender, age, various diseases, and smoking status. Each row in the data provides relavant information about the patient.

# %% [markdown]
# # Attribute Information
# 1) Id: unique identifier
# 2) Gender: "Male", "Female" or "Other"
# 3) Age: age of the patient
# 4) Hypertension: 0 if the patient doesn't have hypertension, 1 if the patient has hypertension
# 5) Heart_disease: 0 if the patient doesn't have any heart diseases, 1 if the patient has a heart disease
# 6) Ever_married: "No" or "Yes"
# 7) Work_type: "children", "Govt_jov", "Never_worked", "Private" or "Self-employed"
# 8) Residence_type: "Rural" or "Urban"
# 9) Avg_glucose_level: average glucose level in blood
# 10) Bmi: body mass index
# 11) Smoking_status: "formerly smoked", "never smoked", "smokes" or "Unknown"*
# 12) Stroke: 1 if the patient had a stroke or 0 if not

# %% [markdown]
# # Importing Necessary Libraries

# %%
# Supressing the warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Importing Numpy and Pandas
import pandas as pd
import numpy as np

# %%
# Importing dataset
df = pd.read_excel("Strokes_data.xlsx")
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0  30669    Male   3.0             0              0           No
# 1  30468    Male  58.0             1              0          Yes
# 2  16523  Female   8.0             0              0           No
# 3  56543  Female  70.0             0              0          Yes
# 4  46136    Male  14.0             0              0           No
#
#       work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0      children          Rural              95.12  18.0              NaN
# 1       Private          Urban              87.96  39.2     never smoked
# 2       Private          Urban             110.89  17.6              NaN
# 3       Private          Rural              69.04  35.9  formerly smoked
# 4  Never_worked          Rural             161.28  19.1              NaN
#
#    stroke
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# # Inspecting the DataFrame

# %%
# To display top 5 rows of the dataset
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0  30669    Male   3.0             0              0           No
# 1  30468    Male  58.0             1              0          Yes
# 2  16523  Female   8.0             0              0           No
# 3  56543  Female  70.0             0              0          Yes
# 4  46136    Male  14.0             0              0           No
#
#       work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0      children          Rural              95.12  18.0              NaN
# 1       Private          Urban              87.96  39.2     never smoked
# 2       Private          Urban             110.89  17.6              NaN
# 3       Private          Rural              69.04  35.9  formerly smoked
# 4  Never_worked          Rural             161.28  19.1              NaN
#
#    stroke
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
# To display last 5 rows of the dataset
df.tail()
# Out:
#           id  gender   age  hypertension  heart_disease ever_married  \
# 43395  56196  Female  10.0             0              0           No
# 43396   5450  Female  56.0             0              0          Yes
# 43397  28375  Female  82.0             1              0          Yes
# 43398  27973    Male  40.0             0              0          Yes
# 43399  36271  Female  82.0             0              0          Yes
#
#       work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 43395  children          Urban              58.64  20.4     never smoked
# 43396  Govt_job          Urban             213.61  55.4  formerly smoked
# 43397   Private          Urban              91.94  28.9  formerly smoked
# 43398   Private          Urban              99.16  33.2     never smoked
# 43399   Private          Urban              79.48  20.6     never smoked
#
#        stroke
# 43395       0
# 43396       0
# 43397       0
# 43398       0
# 43399       0

# %%
# To check the dimensions of the DataFrame
df.shape
# Out:
# (43400, 12)

# %%
# To look at the statistical aspects of the DataFrame
df.describe()
# Out:
#                  id           age  hypertension  heart_disease  \
# count  43400.000000  43400.000000  43400.000000   43400.000000
# mean   36326.142350     42.217894      0.093571       0.047512
# std    21072.134879     22.519649      0.291235       0.212733
# min        1.000000      0.080000      0.000000       0.000000
# 25%    18038.500000     24.000000      0.000000       0.000000
# 50%    36351.500000     44.000000      0.000000       0.000000
# 75%    54514.250000     60.000000      0.000000       0.000000
# max    72943.000000     82.000000      1.000000       1.000000
#
#        avg_glucose_level           bmi        stroke
# count       43400.000000  41938.000000  43400.000000
# mean          104.482750     28.605038      0.018041
# std            43.111751      7.770020      0.133103
# min            55.000000     10.100000      0.000000
# 25%            77.540000     23.200000      0.000000
# 50%            91.580000     27.700000      0.000000
# 75%           112.070000     32.900000      0.000000
# max           291.050000     97.600000      1.000000

# %%
# To see datatype of each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43400 entries, 0 to 43399
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 43400 non-null  int64
#  1   gender             43400 non-null  object
#  2   age                43400 non-null  float64
#  3   hypertension       43400 non-null  int64
#  4   heart_disease      43400 non-null  int64
#  5   ever_married       43400 non-null  object
#  6   work_type          43400 non-null  object
#  7   Residence_type     43400 non-null  object
#  8   avg_glucose_level  43400 non-null  float64
#  9   bmi                41938 non-null  float64
#  10  smoking_status     30108 non-null  object
#  11  stroke             43400 non-null  int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 4.0+ MB

# %%
# Check the missing values
df.isna().sum()
# Out:
# id                       0
# gender                   0
# age                      0
# hypertension             0
# heart_disease            0
# ever_married             0
# work_type                0
# Residence_type           0
# avg_glucose_level        0
# bmi                   1462
# smoking_status       13292
# stroke                   0
# dtype: int64

# %%
df['bmi'].isna().sum()
# Out:
# 1462

# %%
df['bmi'].mean()
# Out:
# 28.605038390004296

# %%
# Give inplace = True -- to fill the missing data permanently

df['bmi'].fillna(df['bmi'].mean(), inplace = True)
df
# Out:
#           id  gender   age  hypertension  heart_disease ever_married  \
# 0      30669    Male   3.0             0              0           No
# 1      30468    Male  58.0             1              0          Yes
# 2      16523  Female   8.0             0              0           No
# 3      56543  Female  70.0             0              0          Yes
# 4      46136    Male  14.0             0              0           No
# ...      ...     ...   ...           ...            ...          ...
# 43395  56196  Female  10.0             0              0           No
# 43396   5450  Female  56.0             0              0          Yes
# 43397  28375  Female  82.0             1              0          Yes
# 43398  27973    Male  40.0             0              0          Yes
# 43399  36271  Female  82.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0          children          Rural              95.12  18.0              NaN
# 1           Private          Urban              87.96  39.2     never smoked
# 2           Private          Urban             110.89  17.6              NaN
# 3           Private          Rural              69.04  35.9  formerly smoked
# 4      Never_worked          Rural             161.28  19.1              NaN
# ...             ...            ...                ...   ...              ...
# 43395      children          Urban              58.64  20.4     never smoked
# 43396      Govt_job          Urban             213.61  55.4  formerly smoked
# 43397       Private          Urban              91.94  28.9  formerly smoked
# 43398       Private          Urban              99.16  33.2     never smoked
# 43399       Private          Urban              79.48  20.6     never smoked
#
#        stroke
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 43395       0
# 43396       0
# 43397       0
# 43398       0
# 43399       0
#
# [43400 rows x 12 columns]

# %%
df['smoking_status'].bfill(inplace = True)
df
# Out:
#           id  gender   age  hypertension  heart_disease ever_married  \
# 0      30669    Male   3.0             0              0           No
# 1      30468    Male  58.0             1              0          Yes
# 2      16523  Female   8.0             0              0           No
# 3      56543  Female  70.0             0              0          Yes
# 4      46136    Male  14.0             0              0           No
# ...      ...     ...   ...           ...            ...          ...
# 43395  56196  Female  10.0             0              0           No
# 43396   5450  Female  56.0             0              0          Yes
# 43397  28375  Female  82.0             1              0          Yes
# 43398  27973    Male  40.0             0              0          Yes
# 43399  36271  Female  82.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0          children          Rural              95.12  18.0     never smoked
# 1           Private          Urban              87.96  39.2     never smoked
# 2           Private          Urban             110.89  17.6  formerly smoked
# 3           Private          Rural              69.04  35.9  formerly smoked
# 4      Never_worked          Rural             161.28  19.1  formerly smoked
# ...             ...            ...                ...   ...              ...
# 43395      children          Urban              58.64  20.4     never smoked
# 43396      Govt_job          Urban             213.61  55.4  formerly smoked
# 43397       Private          Urban              91.94  28.9  formerly smoked
# 43398       Private          Urban              99.16  33.2     never smoked
# 43399       Private          Urban              79.48  20.6     never smoked
#
#        stroke
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 43395       0
# 43396       0
# 43397       0
# 43398       0
# 43399       0
#
# [43400 rows x 12 columns]

# %%
#Export file
df.to_excel("Strokes_data1.xlsx")

# %%
# import file

df1 = pd.read_excel("Strokes_data1.xlsx")
df1.head()
# Out:
#    Unnamed: 0     id  gender   age  hypertension  heart_disease ever_married  \
# 0           0  30669    Male   3.0             0              0           No
# 1           1  30468    Male  58.0             1              0          Yes
# 2           2  16523  Female   8.0             0              0           No
# 3           3  56543  Female  70.0             0              0          Yes
# 4           4  46136    Male  14.0             0              0           No
#
#       work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0      children          Rural              95.12  18.0     never smoked
# 1       Private          Urban              87.96  39.2     never smoked
# 2       Private          Urban             110.89  17.6  formerly smoked
# 3       Private          Rural              69.04  35.9  formerly smoked
# 4  Never_worked          Rural             161.28  19.1  formerly smoked
#
#    stroke
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# # Data Visualization

# %%
# Importing matplotlib and seaborn
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df.head(1)
# Out:
#       id gender  age  hypertension  heart_disease ever_married work_type  \
# 0  30669   Male  3.0             0              0           No  children
#
#   Residence_type  avg_glucose_level   bmi smoking_status  stroke
# 0          Rural              95.12  18.0   never smoked       0

# %% [markdown]
# # Visualizing numeric variable of data set(using pair plot)

# %%
sns.pairplot(df)
plt.savefig("pairplot.png")
plt.show()

# %%
# Shows the Distribution of Heat Diseases with respect to other variables
categorical = ['hypertension', 'heart_disease', 'ever_married', 'work_type', 'Residence_type', 'smoking_status']

for i in categorical:
    sns.countplot(x=df[i],data=df, hue=df['stroke'])
    plt.savefig('plot'+str(i)+'.png')
    plt.show()

# %%
# Shows the Distribution of Heart Diseases with respect to other variables

continuous = ['id', 'age', 'avg_glucose_level', 'bmi']

for i in continuous:
    sns.boxplot(x=df['stroke'],y=df[i],hue = df['stroke'])
    plt.savefig('plot'+str(i)+'.png')
    plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
df.hist(bins=50, figsize=(20,15))
plt.show()

# %%
import seaborn as sns
sns.relplot(data=df, x = "avg_glucose_level", y="bmi", hue = "stroke" )

# %% [markdown]
# # Co-relation plot

# %%
# Let's see the correlation matrix 
plt.figure(figsize = (20,10))        # Size of the figure
sns.heatmap(df.corr(),annot = True,cmap='Blues')
plt.savefig("heatmap.png")
plt.show()

# %%
from pandas.plotting import scatter_matrix

attributes= ["stroke","avg_glucose_level","bmi"]
scatter_matrix(df[attributes], figsize=(15, 10))
# Out:
# array([[<Axes: xlabel='stroke', ylabel='stroke'>,
#         <Axes: xlabel='avg_glucose_level', ylabel='stroke'>,
#         <Axes: xlabel='bmi', ylabel='stroke'>],
#        [<Axes: xlabel='stroke', ylabel='avg_glucose_level'>,
#         <Axes: xlabel='avg_glucose_level', ylabel='avg_glucose_level'>,
#         <Axes: xlabel='bmi', ylabel='avg_glucose_level'>],
#        [<Axes: xlabel='stroke', ylabel='bmi'>,
#         <Axes: xlabel='avg_glucose_level', ylabel='bmi'>,
#         <Axes: xlabel='bmi', ylabel='bmi'>]], dtype=object)

# %% [markdown]
# # Data Processing

# %%
# Checking for NULLs in the data
df.isnull().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43400 entries, 0 to 43399
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 43400 non-null  int64
#  1   gender             43400 non-null  object
#  2   age                43400 non-null  float64
#  3   hypertension       43400 non-null  int64
#  4   heart_disease      43400 non-null  int64
#  5   ever_married       43400 non-null  object
#  6   work_type          43400 non-null  object
#  7   Residence_type     43400 non-null  object
#  8   avg_glucose_level  43400 non-null  float64
#  9   bmi                43400 non-null  float64
#  10  smoking_status     43400 non-null  object
#  11  stroke             43400 non-null  int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 4.0+ MB

# %%
df.describe()
# Out:
#                  id           age  hypertension  heart_disease  \
# count  43400.000000  43400.000000  43400.000000   43400.000000
# mean   36326.142350     42.217894      0.093571       0.047512
# std    21072.134879     22.519649      0.291235       0.212733
# min        1.000000      0.080000      0.000000       0.000000
# 25%    18038.500000     24.000000      0.000000       0.000000
# 50%    36351.500000     44.000000      0.000000       0.000000
# 75%    54514.250000     60.000000      0.000000       0.000000
# max    72943.000000     82.000000      1.000000       1.000000
#
#        avg_glucose_level           bmi        stroke
# count       43400.000000  43400.000000  43400.000000
# mean          104.482750     28.605038      0.018041
# std            43.111751      7.638023      0.133103
# min            55.000000     10.100000      0.000000
# 25%            77.540000     23.400000      0.000000
# 50%            91.580000     28.100000      0.000000
# 75%           112.070000     32.600000      0.000000
# max           291.050000     97.600000      1.000000

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0  30669    Male   3.0             0              0           No
# 1  30468    Male  58.0             1              0          Yes
# 2  16523  Female   8.0             0              0           No
# 3  56543  Female  70.0             0              0          Yes
# 4  46136    Male  14.0             0              0           No
#
#       work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0      children          Rural              95.12  18.0     never smoked
# 1       Private          Urban              87.96  39.2     never smoked
# 2       Private          Urban             110.89  17.6  formerly smoked
# 3       Private          Rural              69.04  35.9  formerly smoked
# 4  Never_worked          Rural             161.28  19.1  formerly smoked
#
#    stroke
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
# Creating a dummy variable for some of the categorical variables and dropping the first one.
dummy = pd.get_dummies(df[['gender','work_type','hypertension','heart_disease','ever_married','Residence_type','smoking_status']], drop_first=True)

# Adding the results to the master dataframe
df = pd.concat([df, dummy], axis=1)

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0  30669    Male   3.0             0              0           No
# 1  30468    Male  58.0             1              0          Yes
# 2  16523  Female   8.0             0              0           No
# 3  56543  Female  70.0             0              0          Yes
# 4  46136    Male  14.0             0              0           No
#
#       work_type Residence_type  avg_glucose_level   bmi  ... gender_Male  \
# 0      children          Rural              95.12  18.0  ...           1
# 1       Private          Urban              87.96  39.2  ...           1
# 2       Private          Urban             110.89  17.6  ...           0
# 3       Private          Rural              69.04  35.9  ...           0
# 4  Never_worked          Rural             161.28  19.1  ...           1
#
#    gender_Other  work_type_Never_worked  work_type_Private  \
# 0             0                       0                  0
# 1             0                       0                  1
# 2             0                       0                  1
# 3             0                       0                  1
# 4             0                       1                  0
#
#    work_type_Self-employed  work_type_children  ever_married_Yes  \
# 0                        0                   1                 0
# 1                        0                   0                 1
# 2                        0                   0                 0
# 3                        0                   0                 1
# 4                        0                   0                 0
#
#    Residence_type_Urban  smoking_status_never smoked  smoking_status_smokes
# 0                     0                            1                      0
# 1                     1                            1                      0
# 2                     1                            0                      0
# 3                     0                            0                      0
# 4                     0                            0                      0
#
# [5 rows x 24 columns]

# %%
# To display maximum rows and columns 

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0  30669    Male   3.0             0              0           No
# 1  30468    Male  58.0             1              0          Yes
# 2  16523  Female   8.0             0              0           No
# 3  56543  Female  70.0             0              0          Yes
# 4  46136    Male  14.0             0              0           No
#
#       work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0      children          Rural              95.12  18.0     never smoked
# 1       Private          Urban              87.96  39.2     never smoked
# 2       Private          Urban             110.89  17.6  formerly smoked
# 3       Private          Rural              69.04  35.9  formerly smoked
# 4  Never_worked          Rural             161.28  19.1  formerly smoked
#
#    stroke  hypertension  heart_disease  gender_Male  gender_Other  \
# 0       0             0              0            1             0
# 1       0             1              0            1             0
# 2       0             0              0            0             0
# 3       0             0              0            0             0
# 4       0             0              0            1             0
#
#    work_type_Never_worked  work_type_Private  work_type_Self-employed  \
# 0                       0                  0                        0
# 1                       0                  1                        0
# 2                       0                  1                        0
# 3                       0                  1                        0
# 4                       1                  0                        0
#
#    work_type_children  ever_married_Yes  Residence_type_Urban  \
# 0                   1                 0                     0
# 1                   0                 1                     1
# 2                   0                 0                     1
# 3                   0                 1                     0
# 4                   0                 0                     0
#
#    smoking_status_never smoked  smoking_status_smokes
# 0                            1                      0
# 1                            1                      0
# 2                            0                      0
# 3                            0                      0
# 4                            0                      0

# %% [markdown]
# # Dropping the repeated variables

# %%
# We have created dummies for the below variables, so we can drop them
df = df.drop(['gender','work_type','hypertension','heart_disease','ever_married','Residence_type','smoking_status'], 1)

# %%
df.head()
# Out:
#       id   age  avg_glucose_level   bmi  stroke  gender_Male  gender_Other  \
# 0  30669   3.0              95.12  18.0       0            1             0
# 1  30468  58.0              87.96  39.2       0            1             0
# 2  16523   8.0             110.89  17.6       0            0             0
# 3  56543  70.0              69.04  35.9       0            0             0
# 4  46136  14.0             161.28  19.1       0            1             0
#
#    work_type_Never_worked  work_type_Private  work_type_Self-employed  \
# 0                       0                  0                        0
# 1                       0                  1                        0
# 2                       0                  1                        0
# 3                       0                  1                        0
# 4                       1                  0                        0
#
#    work_type_children  ever_married_Yes  Residence_type_Urban  \
# 0                   1                 0                     0
# 1                   0                 1                     1
# 2                   0                 0                     1
# 3                   0                 1                     0
# 4                   0                 0                     0
#
#    smoking_status_never smoked  smoking_status_smokes
# 0                            1                      0
# 1                            1                      0
# 2                            0                      0
# 3                            0                      0
# 4                            0                      0

# %% [markdown]
# # Test-Train Split

# %%
from sklearn.model_selection import train_test_split

# %%
# Putting feature variable to X
X = df.drop(['stroke'], axis=1)

X.head()
# Out:
#       id   age  avg_glucose_level   bmi  gender_Male  gender_Other  \
# 0  30669   3.0              95.12  18.0            1             0
# 1  30468  58.0              87.96  39.2            1             0
# 2  16523   8.0             110.89  17.6            0             0
# 3  56543  70.0              69.04  35.9            0             0
# 4  46136  14.0             161.28  19.1            1             0
#
#    work_type_Never_worked  work_type_Private  work_type_Self-employed  \
# 0                       0                  0                        0
# 1                       0                  1                        0
# 2                       0                  1                        0
# 3                       0                  1                        0
# 4                       1                  0                        0
#
#    work_type_children  ever_married_Yes  Residence_type_Urban  \
# 0                   1                 0                     0
# 1                   0                 1                     1
# 2                   0                 0                     1
# 3                   0                 1                     0
# 4                   0                 0                     0
#
#    smoking_status_never smoked  smoking_status_smokes
# 0                            1                      0
# 1                            1                      0
# 2                            0                      0
# 3                            0                      0
# 4                            0                      0

# %%
# Putting response variable to y
y = df['stroke']

y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: stroke, dtype: int64

# %%
# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, test_size=0.3, random_state=100)

# %%
# To check the shape
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((30379, 14), (13020, 14), (30379,), (13020,))

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

X_train[['age','avg_glucose_level','bmi']] = scaler.fit_transform(X_train[['age','avg_glucose_level','bmi']])

X_train.head()
# Out:
#           id       age  avg_glucose_level       bmi  gender_Male  \
# 593    30102  0.633789           0.056516  0.274286            1
# 20743  42517  0.780273           0.144848  0.173714            0
# 22376  57793  0.487305           0.129809  0.205714            1
# 15905  48310  0.707031           0.605660  0.286857            0
# 22414  53452  0.206543           0.037112  0.229714            0
#
#        gender_Other  work_type_Never_worked  work_type_Private  \
# 593               0                       0                  1
# 20743             0                       0                  1
# 22376             0                       0                  1
# 15905             0                       0                  1
# 22414             0                       1                  0
#
#        work_type_Self-employed  work_type_children  ever_married_Yes  \
# 593                          0                   0                 1
# 20743                        0                   0                 1
# 22376                        0                   0                 1
# 15905                        0                   0                 0
# 22414                        0                   0                 0
#
#        Residence_type_Urban  smoking_status_never smoked  \
# 593                       0                            1
# 20743                     0                            1
# 22376                     1                            0
# 15905                     0                            1
# 22414                     0                            1
#
#        smoking_status_smokes
# 593                        0
# 20743                      0
# 22376                      0
# 15905                      0
# 22414                      0

# %%
X_test.head()
# Out:
#           id   age  avg_glucose_level   bmi  gender_Male  gender_Other  \
# 38218  59462  62.0              72.53  34.4            1             0
# 37883  38919  52.0              61.88  26.5            1             0
# 20297  50827  74.0              66.02  25.6            0             0
# 41591  53966  34.0              75.44  26.8            1             0
# 9542   57696  60.0              99.41  30.8            0             0
#
#        work_type_Never_worked  work_type_Private  work_type_Self-employed  \
# 38218                       0                  1                        0
# 37883                       0                  1                        0
# 20297                       0                  1                        0
# 41591                       0                  1                        0
# 9542                        0                  0                        0
#
#        work_type_children  ever_married_Yes  Residence_type_Urban  \
# 38218                   0                 1                     1
# 37883                   0                 1                     0
# 20297                   0                 1                     0
# 41591                   0                 1                     0
# 9542                    0                 1                     0
#
#        smoking_status_never smoked  smoking_status_smokes
# 38218                            0                      0
# 37883                            0                      1
# 20297                            1                      0
# 41591                            0                      1
# 9542                             1                      0

# %%
#scaler = MinMaxScaler()

X_test[['age','avg_glucose_level','bmi']] = scaler.fit_transform(X_test[['age','avg_glucose_level','bmi']])

X_test.head()
# Out:
#           id       age  avg_glucose_level       bmi  gender_Male  \
# 38218  59462  0.755859           0.078413  0.305838            1
# 37883  38919  0.633789           0.030775  0.205584            1
# 20297  50827  0.902344           0.049293  0.194162            0
# 41591  53966  0.414062           0.091430  0.209391            1
# 9542   57696  0.731445           0.198649  0.260152            0
#
#        gender_Other  work_type_Never_worked  work_type_Private  \
# 38218             0                       0                  1
# 37883             0                       0                  1
# 20297             0                       0                  1
# 41591             0                       0                  1
# 9542              0                       0                  0
#
#        work_type_Self-employed  work_type_children  ever_married_Yes  \
# 38218                        0                   0                 1
# 37883                        0                   0                 1
# 20297                        0                   0                 1
# 41591                        0                   0                 1
# 9542                         0                   0                 1
#
#        Residence_type_Urban  smoking_status_never smoked  \
# 38218                     1                            0
# 37883                     0                            0
# 20297                     0                            1
# 41591                     0                            0
# 9542                      0                            1
#
#        smoking_status_smokes
# 38218                      0
# 37883                      1
# 20297                      0
# 41591                      1
# 9542                       0

# %% [markdown]
# # Model Building

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
# Training data is used for model building
lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# Testing data is used for prediction
y_pred_logreg = lr.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_pred_logreg)
# Out:
# 0.9834101382488479

# %%
# Libraries for Validation of models
from sklearn.metrics import confusion_matrix

# %%
logistic_confusion_matrix = confusion_matrix(y_test, y_pred_logreg)
logistic_confusion_matrix
# Out:
# array([[12804,     0],
#        [  216,     0]], dtype=int64)

# %%
plt.figure(figsize = (3,3))      
sns.heatmap(logistic_confusion_matrix,annot=True,cmap='Blues',vmax=5000,vmin=0,fmt=".0f")
plt.savefig("logistic_confusion_matrix.png")
plt.show()

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# %%
# Function For Logistic Regression Create Summary For Logistic Regression

def plot_roc_curve(fpr, tpr):
    plt.plot(fpr, tpr, color='orange', lw=2,linestyle='--')
    plt.plot([0, 1], [0, 1], color='darkblue', linestyle=':')
    plt.xlabel('False Positive Rate(1-specificity)')
    plt.ylabel('True Positive Rate (sensitivity)')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend()
    plt.show()

def get_summary(y_test, y_pred_logreg):
    # Confusion Matrix
    conf_mat = confusion_matrix(y_test, y_pred_logreg)
    TP = conf_mat[0,0:1]
    FP = conf_mat[0,1:2]
    FN = conf_mat[1,0:1]
    TN = conf_mat[1,1:2]
    
    accuracy = (TP+TN)/((FN+FP)+(TP+TN))
    sensitivity = TP/(TP+FN)
    specificity = TN/(TN+FP)
    precision = TP/(TP+FP)
    recall =  TP / (TP + FN)
    fScore = (2 * recall * precision) / (recall + precision)
    auc = roc_auc_score(y_test, y_pred_logreg)

    print("Confusion Matrix:\n",conf_mat)
    print("Accuracy:",accuracy)
    print("Sensitivity :",sensitivity)
    print("Specificity :",specificity)
    print("Precision:",precision)
    print("Recall:",recall)
    print("F-score:",fScore)
    print("AUC:",auc)
    print("ROC curve:")
    fpr, tpr, thresholds = roc_curve(y_test, y_pred_logreg)
    plot_roc_curve(fpr, tpr)

# %%
get_summary(y_test, y_pred_logreg)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Confusion Matrix:
#  [[12804     0]
#  [  216     0]]
# Accuracy: [0.98341014]
# Sensitivity : [0.98341014]
# Specificity : [nan]
# Precision: [1.]
# Recall: [0.98341014]
# F-score: [0.99163569]
# AUC: 0.5
# ROC curve:

# %% [markdown]
# # Support Vector Machine

# %%
X_train.head()
# Out:
#           id       age  avg_glucose_level       bmi  gender_Male  \
# 593    30102  0.633789           0.056516  0.274286            1
# 20743  42517  0.780273           0.144848  0.173714            0
# 22376  57793  0.487305           0.129809  0.205714            1
# 15905  48310  0.707031           0.605660  0.286857            0
# 22414  53452  0.206543           0.037112  0.229714            0
#
#        gender_Other  work_type_Never_worked  work_type_Private  \
# 593               0                       0                  1
# 20743             0                       0                  1
# 22376             0                       0                  1
# 15905             0                       0                  1
# 22414             0                       1                  0
#
#        work_type_Self-employed  work_type_children  ever_married_Yes  \
# 593                          0                   0                 1
# 20743                        0                   0                 1
# 22376                        0                   0                 1
# 15905                        0                   0                 0
# 22414                        0                   0                 0
#
#        Residence_type_Urban  smoking_status_never smoked  \
# 593                       0                            1
# 20743                     0                            1
# 22376                     1                            0
# 15905                     0                            1
# 22414                     0                            1
#
#        smoking_status_smokes
# 593                        0
# 20743                      0
# 22376                      0
# 15905                      0
# 22414                      0

# %%
y_train.head()
# Out:
# 593      0
# 20743    0
# 22376    0
# 15905    0
# 22414    0
# Name: stroke, dtype: int64

# %%
from sklearn.svm import SVC

# %%
svc = SVC()

# %%
svc.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_pred_svc = svc.predict(X_test)

# %%
accuracy_score(y_test, y_pred_svc)
# Out:
# 0.9834101382488479

# %%
SVM_confusion_matrix = confusion_matrix(y_test, y_pred_svc)
SVM_confusion_matrix
# Out:
# array([[12804,     0],
#        [  216,     0]], dtype=int64)

# %%
plt.figure(figsize = (5,5))      
sns.heatmap(SVM_confusion_matrix,annot=True,cmap='Blues',fmt=".0f")
plt.savefig("SVM_confusion_matrix.png")
plt.show()

# %%
get_summary(y_test, y_pred_svc)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Confusion Matrix:
#  [[12804     0]
#  [  216     0]]
# Accuracy: [0.98341014]
# Sensitivity : [0.98341014]
# Specificity : [nan]
# Precision: [1.]
# Recall: [0.98341014]
# F-score: [0.99163569]
# AUC: 0.5
# ROC curve:

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
DecisionTreeClassifier()
# Out:
# DecisionTreeClassifier()

# %%
y_pred_dtree = dtree.predict(X_test)

# %%
accuracy_score(y_test, y_pred_dtree)
# Out:
# 0.9641321044546851

# %%
dtree_confusion_matrix = confusion_matrix(y_test, y_pred_dtree)
dtree_confusion_matrix
# Out:
# array([[12539,   265],
#        [  202,    14]], dtype=int64)

# %%
plt.figure(figsize = (5,5))      
sns.heatmap(dtree_confusion_matrix ,annot=True,cmap='Blues',fmt=".0f")
plt.savefig("dtree_confusion_matrix.png")
plt.show()

# %%
get_summary(y_test, y_pred_dtree)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Confusion Matrix:
#  [[12539   265]
#  [  202    14]]
# Accuracy: [0.9641321]
# Sensitivity : [0.98414567]
# Specificity : [0.05017921]
# Precision: [0.97930334]
# Recall: [0.98414567]
# F-score: [0.98171854]
# AUC: 0.5220590787601097
# ROC curve:

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_rfc = rfc.predict(X_test)

# %%
accuracy_score(y_test, y_pred_rfc)
# Out:
# 0.9833333333333333

# %%
RandomForest_confusion_matrix = confusion_matrix(y_test, y_pred_rfc)
RandomForest_confusion_matrix
# Out:
# array([[12803,     1],
#        [  216,     0]], dtype=int64)

# %%
plt.figure(figsize = (5,5))      
sns.heatmap(RandomForest_confusion_matrix ,annot=True,cmap='Blues',fmt=".0f")
plt.savefig("RandomForest_confusion_matrix.png")
plt.show()

# %%
get_summary(y_test, y_pred_rfc)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Confusion Matrix:
#  [[12803     1]
#  [  216     0]]
# Accuracy: [0.98333333]
# Sensitivity : [0.98340886]
# Specificity : [0.]
# Precision: [0.9999219]
# Recall: [0.98340886]
# F-score: [0.99159664]
# AUC: 0.49996094970321775
# ROC curve:

# %% [markdown]
# # K - Nearest Neighbour

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
KNeighborsClassifier()
# Out:
# KNeighborsClassifier()

# %%
y_pred_knn = knn.predict(X_test)

# %%
accuracy_score(y_test, y_pred_knn)
# Out:
# 0.9831797235023041

# %%
knn_confusion_matrix = confusion_matrix(y_test, y_pred_knn)
knn_confusion_matrix
# Out:
# array([[12801,     3],
#        [  216,     0]], dtype=int64)

# %%
plt.figure(figsize = (5,5))      
sns.heatmap(knn_confusion_matrix ,annot=True,cmap='Blues',fmt=".0f")
plt.savefig("knn_confusion_matrix.png")
plt.show()

# %%
get_summary(y_test, y_pred_knn)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Confusion Matrix:
#  [[12801     3]
#  [  216     0]]
# Accuracy: [0.98317972]
# Sensitivity : [0.98340631]
# Specificity : [0.]
# Precision: [0.9997657]
# Recall: [0.98340631]
# F-score: [0.99151853]
# AUC: 0.49988284910965325
# ROC curve:

# %%
Summary={'y_pred_logreg':98.3, 'y_pred_svc':98.3,'y_pred_dtree':96.3,'y_pred_rfc':98.3,'y_pred_knn':98.3}
Algorithm = list(Summary.keys())
values = list(Summary.values())
fig = plt.figure(figsize = (10, 5))
plt.bar(Algorithm, values, width = 0.4)
plt.savefig("Summary.png")
plt.show()

# %%
Accuracy={"Algorithm": ["Logisticregression", "SVM", "Decisiontree", "RFC","KNN"],
        "accuracy": [98.3,98.3,96.3,98.3,98.3]}

# %%
df = pd.DataFrame(Accuracy, columns=['Algorithm', 'accuracy'])
df
# Out:
#             Algorithm  accuracy
# 0  Logisticregression      98.3
# 1                 SVM      98.3
# 2        Decisiontree      96.3
# 3                 RFC      98.3
# 4                 KNN      98.3

# %%
plt.figure(figsize=(6, 6))
plots = sns.barplot(x="Algorithm", y="accuracy", width=0.4, data=df)
plt.xlabel("Algorithm", size=10)
plt.ylabel("Accuracy", size=10)
plt.show()
plt.savefig('Accuracy.png')

# %%
plots = sns.barplot(x="Algorithm", y="accuracy", width=0.5, data=df)
for bar in plots.patches:
    plots.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=15, xytext=(0, 8),
                   textcoords='offset points')

# %% [markdown]
# # Thank You!
